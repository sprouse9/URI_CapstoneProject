# %%
import cv2

# %%
cv2.__version__
# Out:
# '4.10.0'

# %%
import matplotlib.pyplot as plt

# Load an image (replace with your image path)
imagepath = "/Users/randy/DSP577/URI_CapstoneProject/images/exampleframe.jpg"
image = cv2.imread(imagepath)

# Convert BGR to RGB (OpenCV loads images in BGR by default)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Display the image using matplotlib
plt.imshow(image_rgb)
plt.axis('off')  # Turn off axis
plt.show()

# %%
import torch
from ultralytics import YOLO

print("PyTorch Version:", torch.__version__)

model = YOLO("yolov8s.pt")
results = model(imagepath)
#print(results)
# Out:
# PyTorch Version: 2.2.2
#
# image 1/1 /Users/randy/DSP577/URI_CapstoneProject/images/exampleframe.jpg: 384x640 9 cars, 1 umbrella, 182.1ms
# Speed: 2.3ms preprocess, 182.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
